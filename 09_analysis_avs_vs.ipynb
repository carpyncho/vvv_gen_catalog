# %%
import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt

import seaborn as sns

# %%
results = np.load("data/o3o4vZ/all_vs_all_vs/results.npy")[0]

results["big"]["b234"].vss
# Out:
# <Container({'b247': <type 'tuple'>, 'b248': <type 'tuple'>, 'b262': <type 'tuple'>, 'b263': <type 'tuple'>, 'b261': <type 'tuple'>, 'b264': <type 'tuple'>, 'b277': <type 'tuple'>, 'b278': <type 'tuple'>})>

# %%
SIZES = {
    "big": "Grd",
    "small": u"Peq",
    "mid": "Med"
}

rows = []
for size in ["small", "mid", "big"]:
    sdata = results[size]
    for train, tdata in sorted(sdata.items()):
        row = {
            "Muestra": SIZES[size],
            "Entr.": train, 
            (train, "prec"): tdata.kfold[0], 
            (train, "rec"): tdata.kfold[1]}
        for k, v in sorted(tdata.vss.items()):
            row.update({(k, "prec"): v[0], (k, "rec"): v[1]})
        rows.append(row)
        

def hl_kfold(row):
    test = row.name[-1]
    styles = []
    for k, v in row.iteritems():
        styles.append(
            'background-color: lightgrey'
            if k[0] == test else
            "")
    return styles

# %%
raw = pd.DataFrame(rows).set_index(["Muestra", "Entr."])
raw.columns = pd.MultiIndex.from_tuples(raw.columns.values)
raw.to_csv("data/o3o4vZ/all_vs_all_vs/raw.csv", encoding='utf-8')
raw.to_pickle("data/o3o4vZ/all_vs_all_vs/raw.pkl")

with pd.option_context('display.precision', 4):
    html = raw.style.apply(hl_kfold, axis=1)
html
# Out:
# <style  type="text/css" >
#     #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row0_col0 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row0_col1 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row1_col2 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row1_col3 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row2_col4 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row2_col5 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row3_col6 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row3_col7 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row4_col8 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row4_col9 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row5_col10 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row5_col11 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row6_col12 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row6_col13 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row7_col14 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row7_col15 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row8_col16 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row8_col17 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row9_col0 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row9_col1 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row10_col2 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row10_col3 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row11_col4 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row11_col5 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row12_col6 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row12_col7 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row13_col8 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row13_col9 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row14_col10 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row14_col11 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row15_col12 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row15_col13 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row16_col14 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row16_col15 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row17_col16 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row17_col17 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row18_col0 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row18_col1 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row19_col2 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row19_col3 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row20_col4 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row20_col5 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row21_col6 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row21_col7 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row22_col8 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row22_col9 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row23_col10 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row23_col11 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row24_col12 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row24_col13 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row25_col14 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row25_col15 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row26_col16 {
#             background-color:  lightgrey;
#         }    #T_9af01692_fcc6_11e8_ba21_fb61b88e51f2row26_col17 {
#             background-color:  lightgrey;
#         }</style>
# <table id="T_9af01692_fcc6_11e8_ba21_fb61b88e51f2" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" colspan=2>b234</th>
#         <th class="col_heading level0 col2" colspan=2>b247</th>
#         <th class="col_heading level0 col4" colspan=2>b248</th>
#         <th class="col_heading level0 col6" colspan=2>b261</th>
#         <th class="col_heading level0 col8" colspan=2>b262</th>
#         <th class="col_heading level0 col10" colspan=2>b263</th>
#         <th class="col_heading level0 col12" colspan=2>b264</th>
#         <th class="col_heading level0 col14" colspan=2>b277</th>
#         <th class="col_heading level0 col16" colspan=2>b278</th>
#     </tr>    <tr>
#         <th class="blank" ></th>
#         <th class="blank level1" ></th>
#         <th class="col_heading level1 col0" >prec</th>
#         <th class="col_heading level1 col1" >rec</th>
#         <th class="col_heading level1 col2" >prec</th>
#         <th class="col_heading level1 col3" >rec</th>
#         <th class="col_heading level1 col4" >prec</th>
#         <th class="col_heading level1 col5" >rec</th>
#         <th class="col_heading level1 col6" >prec</th>
#         <th class="col_heading level1 col7" >rec</th>
#         <th class="col_heading level1 col8" >prec</th>
#         <th class="col_heading level1 col9" >rec</th>
#         <th class="col_heading level1 col10" >prec</th>
#         <th class="col_heading level1 col11" >rec</th>
#         <th class="col_heading level1 col12" >prec</th>
#         <th class="col_heading level1 col13" >rec</th>
#         <th class="col_heading level1 col14" >prec</th>
#         <th class="col_heading level1 col15" >rec</th>
#         <th class="col_heading level1 col16" >prec</th>
#         <th class="col_heading level1 col17" >rec</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Muestra</th>
#         <th class="index_name level1" >Entr.</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class=

# %%
def norm_kfold(row):
    test = row.name[-1]
#     row.swaplevel(0, 1, axis=1)[["prec"]]
#     print row.swaplevel()["prec"].sum()
    denom = {
        "prec": row.swaplevel()["prec"].std(),
        "rec": row.swaplevel()["rec"].std()}
    means = {
        "prec": row.swaplevel()["prec"].mean(),
        "rec": row.swaplevel()["rec"].mean()}
    empty = {}
    for k, v in row.iteritems():
        d = denom[k[1]]
        mean = means[k[1]]
        empty[k] = (v  - mean)/ d
    return empty
    
norm = raw.apply(norm_kfold, axis=1)
# norm.to_csv("data/o3o4vZ/all_vs_all_vs/norm.csv", encoding='utf-8')
# norm.to_pickle("data/o3o4vZ/all_vs_all_vs/norm.pkl")

with pd.option_context('display.precision', 4):
    html = norm.style.apply(hl_kfold, axis=1)
html
# Out:
# <style  type="text/css" >
#     #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row0_col0 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row0_col1 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row1_col2 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row1_col3 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row2_col4 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row2_col5 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row3_col6 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row3_col7 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row4_col8 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row4_col9 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row5_col10 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row5_col11 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row6_col12 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row6_col13 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row7_col14 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row7_col15 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row8_col16 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row8_col17 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row9_col0 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row9_col1 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row10_col2 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row10_col3 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row11_col4 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row11_col5 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row12_col6 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row12_col7 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row13_col8 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row13_col9 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row14_col10 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row14_col11 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row15_col12 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row15_col13 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row16_col14 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row16_col15 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row17_col16 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row17_col17 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row18_col0 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row18_col1 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row19_col2 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row19_col3 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row20_col4 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row20_col5 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row21_col6 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row21_col7 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row22_col8 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row22_col9 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row23_col10 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row23_col11 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row24_col12 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row24_col13 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row25_col14 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row25_col15 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row26_col16 {
#             background-color:  lightgrey;
#         }    #T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2row26_col17 {
#             background-color:  lightgrey;
#         }</style>
# <table id="T_9c54fe8a_fcc6_11e8_ba21_fb61b88e51f2" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" colspan=2>b234</th>
#         <th class="col_heading level0 col2" colspan=2>b247</th>
#         <th class="col_heading level0 col4" colspan=2>b248</th>
#         <th class="col_heading level0 col6" colspan=2>b261</th>
#         <th class="col_heading level0 col8" colspan=2>b262</th>
#         <th class="col_heading level0 col10" colspan=2>b263</th>
#         <th class="col_heading level0 col12" colspan=2>b264</th>
#         <th class="col_heading level0 col14" colspan=2>b277</th>
#         <th class="col_heading level0 col16" colspan=2>b278</th>
#     </tr>    <tr>
#         <th class="blank" ></th>
#         <th class="blank level1" ></th>
#         <th class="col_heading level1 col0" >prec</th>
#         <th class="col_heading level1 col1" >rec</th>
#         <th class="col_heading level1 col2" >prec</th>
#         <th class="col_heading level1 col3" >rec</th>
#         <th class="col_heading level1 col4" >prec</th>
#         <th class="col_heading level1 col5" >rec</th>
#         <th class="col_heading level1 col6" >prec</th>
#         <th class="col_heading level1 col7" >rec</th>
#         <th class="col_heading level1 col8" >prec</th>
#         <th class="col_heading level1 col9" >rec</th>
#         <th class="col_heading level1 col10" >prec</th>
#         <th class="col_heading level1 col11" >rec</th>
#         <th class="col_heading level1 col12" >prec</th>
#         <th class="col_heading level1 col13" >rec</th>
#         <th class="col_heading level1 col14" >prec</th>
#         <th class="col_heading level1 col15" >rec</th>
#         <th class="col_heading level1 col16" >prec</th>
#         <th class="col_heading level1 col17" >rec</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Muestra</th>
#         <th class="index_name level1" >Entr.</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class=

# %% [markdown]
# ## Todas las muestras

# %%
fig, ax = plt.subplots(1, 2, figsize=(18, 8))

df = norm

sns.heatmap(df.swaplevel(0, 1, axis=1)[["prec"]], annot=True, fmt='.4f',  linewidths=.5, ax=ax[0]);

sns.heatmap(df.swaplevel(0, 1, axis=1)[["rec"]], annot=True, linewidths=.5, ax=ax[1]);

labels = [l.get_text().split("-", 1)[-1] for l in ax[0].get_xticklabels()]
ax[0].set_xticklabels(labels)
ax[1].set_xticklabels(labels)

ax[0].set_title("Precision")
ax[1].set_title("Recall")

ax[0].set_xlabel("Prueba")
ax[1].set_xlabel("Prueba")

plt.show()

# %% [markdown]
# ## Muestra Pequeña (2500)

# %%
fig, ax = plt.subplots(1, 2, figsize=(18, 8))

df = norm.loc["Peq"]

sns.heatmap(df.swaplevel(0, 1, axis=1)[["prec"]], annot=True, fmt='.4f',  linewidths=.5, ax=ax[0]);

sns.heatmap(df.swaplevel(0, 1, axis=1)[["rec"]], annot=True, linewidths=.5, ax=ax[1]);

labels = [l.get_text().split("-", 1)[-1] for l in ax[0].get_xticklabels()]
ax[0].set_xticklabels(labels)
ax[1].set_xticklabels(labels)

ax[0].set_title("Precision")
ax[1].set_title("Recall")

ax[0].set_xlabel("Prueba")
ax[1].set_xlabel("Prueba")

plt.show()

# %% [markdown]
# ## Muestra Mediana (5000)

# %%
fig, ax = plt.subplots(1, 2, figsize=(18, 8))

df = norm.loc["Med"]

sns.heatmap(df.swaplevel(0, 1, axis=1)[["prec"]], annot=True, fmt='.4f',  linewidths=.5, ax=ax[0]);

sns.heatmap(df.swaplevel(0, 1, axis=1)[["rec"]], annot=True, linewidths=.5, ax=ax[1]);

labels = [l.get_text().split("-", 1)[-1] for l in ax[0].get_xticklabels()]
ax[0].set_xticklabels(labels)
ax[1].set_xticklabels(labels)

ax[0].set_title("Precision")
ax[1].set_title("Recall")

ax[0].set_xlabel("Prueba")
ax[1].set_xlabel("Prueba")

plt.show()

# %% [markdown]
# ## Muestra Grande (20K)

# %%
fig, ax = plt.subplots(1, 2, figsize=(18, 8))

df = norm.loc["Grd"]

sns.heatmap(df.swaplevel(0, 1, axis=1)[["prec"]], annot=True, fmt='.4f',  linewidths=.5, ax=ax[0]);

sns.heatmap(df.swaplevel(0, 1, axis=1)[["rec"]], annot=True, linewidths=.5, ax=ax[1]);

labels = [l.get_text().split("-", 1)[-1] for l in ax[0].get_xticklabels()]
ax[0].set_xticklabels(labels)
ax[1].set_xticklabels(labels)

ax[0].set_title("Precision")
ax[1].set_title("Recall")

ax[0].set_xlabel("Prueba")
ax[1].set_xlabel("Prueba")

plt.show()

# %%
df.swaplevel(0, 1, axis=1)[["prec"]].T.plot()

# %%
df.swaplevel(0, 1, axis=1)[["rec"]].T.plot()
