# %%
import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt

import seaborn as sns

# %%
results = np.load("data/o3o4vZ/all_vs_all_vs/results.npy")[0]

results["big"]["b234"].vss
# Out:
# <Container({'b396': <type 'tuple'>, 'b247': <type 'tuple'>, 'b248': <type 'tuple'>, 'b262': <type 'tuple'>, 'b263': <type 'tuple'>, 'b261': <type 'tuple'>, 'b264': <type 'tuple'>, 'b277': <type 'tuple'>, 'b278': <type 'tuple'>, 'b220': <type 'tuple'>})>

# %%
SIZES = {
    "big": "Grd",
    "small": u"Peq",
    "mid": "Med"
}

rows = []
for size in ["small", "mid", "big"]:
    sdata = results[size]
    for train, tdata in sorted(sdata.items()):
        row = {
            "Muestra": SIZES[size],
            "Entr.": train, 
            (train, "prec"): tdata.kfold[0], 
            (train, "rec"): tdata.kfold[1]}
        for k, v in sorted(tdata.vss.items()):
            row.update({(k, "prec"): v[0], (k, "rec"): v[1]})
        rows.append(row)
        

def hl_kfold(row):
    test = row.name[-1]
    styles = []
    for k, v in row.iteritems():
        styles.append(
            'background-color: lightgrey'
            if k[0] == test else
            "")
    return styles

# %%
raw = pd.DataFrame(rows).set_index(["Muestra", "Entr."])
raw.columns = pd.MultiIndex.from_tuples(raw.columns.values)
raw.to_csv("data/o3o4vZ/all_vs_all_vs/raw.csv", encoding='utf-8')
raw.to_pickle("data/o3o4vZ/all_vs_all_vs/raw.pkl")

with pd.option_context('display.precision', 4):
    html = raw.style.apply(hl_kfold, axis=1)
html
# Out:
# <style  type="text/css" >
#     #T_b7e2372e_0420_11e9_8517_e7337ad8948erow0_col0 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow0_col1 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow1_col2 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow1_col3 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow2_col4 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow2_col5 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow3_col6 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow3_col7 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow4_col8 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow4_col9 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow5_col10 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow5_col11 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow6_col12 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow6_col13 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow7_col14 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow7_col15 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow8_col16 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow8_col17 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow9_col18 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow9_col19 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow10_col20 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow10_col21 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow11_col0 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow11_col1 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow12_col2 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow12_col3 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow13_col4 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow13_col5 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow14_col6 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow14_col7 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow15_col8 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow15_col9 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow16_col10 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow16_col11 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow17_col12 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow17_col13 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow18_col14 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow18_col15 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow19_col16 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow19_col17 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow20_col18 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow20_col19 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow21_col20 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow21_col21 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow22_col0 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow22_col1 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow23_col2 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow23_col3 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow24_col4 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow24_col5 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow25_col6 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow25_col7 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow26_col8 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow26_col9 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow27_col10 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow27_col11 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow28_col12 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow28_col13 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow29_col14 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow29_col15 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow30_col16 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow30_col17 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow31_col18 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow31_col19 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow32_col20 {
#             background-color:  lightgrey;
#         }    #T_b7e2372e_0420_11e9_8517_e7337ad8948erow32_col21 {
#             background-color:  lightgrey;
#         }</style>
# <table id="T_b7e2372e_0420_11e9_8517_e7337ad8948e" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" colspan=2>b220</th>
#         <th class="col_heading level0 col2" colspan=2>b234</th>
#         <th class="col_heading level0 col4" colspan=2>b247</th>
#         <th class="col_heading level0 col6" colspan=2>b248</th>
#         <th class="col_heading level0 col8" colspan=2>b261</th>
#         <th class="col_heading level0 col10" colspan=2>b262</th>
#         <th class="col_heading level0 col12" colspan=2>b263</th>
#         <th class="col_heading level0 col14" colspan=2>b264</th>
#         <th class="col_heading level0 col16" colspan=2>b277</th>
#         <th class="col_heading level0 col18" colspan=2>b278</th>
#         <th class="col_heading level0 col20" colspan=2>b396</th>
#     </tr>    <tr>

# %%
def norm_kfold(row):
    test = row.name[-1]
#     row.swaplevel(0, 1, axis=1)[["prec"]]
#     print row.swaplevel()["prec"].sum()
    denom = {
        "prec": row.swaplevel()["prec"].std(),
        "rec": row.swaplevel()["rec"].std()}
    means = {
        "prec": row.swaplevel()["prec"].mean(),
        "rec": row.swaplevel()["rec"].mean()}
    empty = {}
    for k, v in row.iteritems():
        d = denom[k[1]]
        mean = means[k[1]]
        empty[k] = (v  - mean)/ d
    return empty
    
norm = raw.apply(norm_kfold, axis=1)
# norm.to_csv("data/o3o4vZ/all_vs_all_vs/norm.csv", encoding='utf-8')
# norm.to_pickle("data/o3o4vZ/all_vs_all_vs/norm.pkl")

with pd.option_context('display.precision', 4):
    html = norm.style.apply(hl_kfold, axis=1)
html
# Out:
# <style  type="text/css" >
#     #T_b9d0c230_0420_11e9_8517_e7337ad8948erow0_col0 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow0_col1 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow1_col2 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow1_col3 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow2_col4 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow2_col5 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow3_col6 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow3_col7 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow4_col8 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow4_col9 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow5_col10 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow5_col11 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow6_col12 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow6_col13 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow7_col14 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow7_col15 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow8_col16 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow8_col17 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow9_col18 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow9_col19 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow10_col20 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow10_col21 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow11_col0 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow11_col1 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow12_col2 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow12_col3 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow13_col4 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow13_col5 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow14_col6 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow14_col7 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow15_col8 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow15_col9 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow16_col10 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow16_col11 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow17_col12 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow17_col13 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow18_col14 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow18_col15 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow19_col16 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow19_col17 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow20_col18 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow20_col19 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow21_col20 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow21_col21 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow22_col0 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow22_col1 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow23_col2 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow23_col3 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow24_col4 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow24_col5 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow25_col6 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow25_col7 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow26_col8 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow26_col9 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow27_col10 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow27_col11 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow28_col12 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow28_col13 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow29_col14 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow29_col15 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow30_col16 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow30_col17 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow31_col18 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow31_col19 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow32_col20 {
#             background-color:  lightgrey;
#         }    #T_b9d0c230_0420_11e9_8517_e7337ad8948erow32_col21 {
#             background-color:  lightgrey;
#         }</style>
# <table id="T_b9d0c230_0420_11e9_8517_e7337ad8948e" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" colspan=2>b220</th>
#         <th class="col_heading level0 col2" colspan=2>b234</th>
#         <th class="col_heading level0 col4" colspan=2>b247</th>
#         <th class="col_heading level0 col6" colspan=2>b248</th>
#         <th class="col_heading level0 col8" colspan=2>b261</th>
#         <th class="col_heading level0 col10" colspan=2>b262</th>
#         <th class="col_heading level0 col12" colspan=2>b263</th>
#         <th class="col_heading level0 col14" colspan=2>b264</th>
#         <th class="col_heading level0 col16" colspan=2>b277</th>
#         <th class="col_heading level0 col18" colspan=2>b278</th>
#         <th class="col_heading level0 col20" colspan=2>b396</th>
#     </tr>    <tr>

# %% [markdown]
# ## Todas las muestras

# %%
fig, ax = plt.subplots(1, 2, figsize=(18, 8))

df = raw

sns.heatmap(df.swaplevel(0, 1, axis=1)[["prec"]], annot=True, fmt='.4f',  linewidths=.5, ax=ax[0]);

sns.heatmap(df.swaplevel(0, 1, axis=1)[["rec"]], annot=True, linewidths=.5, ax=ax[1]);

labels = [l.get_text().split("-", 1)[-1] for l in ax[0].get_xticklabels()]
ax[0].set_xticklabels(labels)
ax[1].set_xticklabels(labels)

ax[0].set_title("Precision")
ax[1].set_title("Recall")

ax[0].set_xlabel("Prueba")
ax[1].set_xlabel("Prueba")

plt.show()

# %% [markdown]
# ## Muestra Pequeña (2500)

# %%
fig, aax = plt.subplots(3, 2, figsize=(18, 22))

def draw(ax, df, suffix):
    sns.heatmap(df.swaplevel(0, 1, axis=1)[["prec"]], annot=True, fmt='.3f',  linewidths=.5, ax=ax[0]);

    sns.heatmap(df.swaplevel(0, 1, axis=1)[["rec"]], annot=True, fmt='.3f', linewidths=.5, ax=ax[1]);

    labels = [l.get_text().split("-", 1)[-1] for l in ax[0].get_xticklabels()]
    ax[0].set_xticklabels(labels)
    ax[1].set_xticklabels(labels)

    ax[0].set_title(u"Precision - M.{}".format(suffix))
    ax[1].set_title(u"Recall - M.{}".format(suffix))

    ax[0].set_xlabel("Prueba")
    ax[1].set_xlabel("Prueba")

draw(ax=aax[0], df=raw.loc["Peq"], suffix=u"Pequeña")
draw(ax=aax[1], df=raw.loc["Med"], suffix=u"Mediana")
draw(ax=aax[2], df=raw.loc["Grd"], suffix=u"Grande")

plt.savefig("workpoint.pdf")
plt.show()

# %%
df.swaplevel(0, 1, axis=1)[["prec"]].T.plot()

# %%
df.swaplevel(0, 1, axis=1)[["rec"]].T.plot()
